# %%
import matplotlib.pyplot as plt
import pandas as pd
import dataframe_image as dfi

# %%
data = {'num_of_images': [10, 100, 500, 1000], 'time_taken': [0.905, 5.544, 25.228, 50.883]}
df = pd.DataFrame(data)
df
# Out:
#    num_of_images  time_taken
# 0             10       0.905
# 1            100       5.544
# 2            500      25.228
# 3           1000      50.883

# %%
df.plot(kind='line', x='num_of_images', y='time_taken', color='blue')
plt.xlabel("Number of Images")
plt.ylabel("Time Taken to Run Model")
plt.title("MesoNet Performance Graph")
plt.savefig('mesonet_graph.png')
# plt.show()
